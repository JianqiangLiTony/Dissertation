# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %%
data = pd.read_csv('UK House price index Sales Volume.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 46 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  325 non-null    object
#  1   City of London        325 non-null    int64
#  2   Barking & Dagenham    325 non-null    int64
#  3   Barnet                325 non-null    int64
#  4   Bexley                325 non-null    int64
#  5   Brent                 325 non-null    int64
#  6   Bromley               325 non-null    int64
#  7   Camden                325 non-null    int64
#  8   Croydon               325 non-null    int64
#  9   Ealing                325 non-null    int64
#  10  Enfield               325 non-null    int64
#  11  Greenwich             325 non-null    int64
#  12  Hackney               325 non-null    int64
#  13  Hammersmith & Fulham  325 non-null    int64
#  14  Haringey              325 non-null    int64
#  15  Harrow                325 non-null    int64
#  16  Havering              325 non-null    int64
#  17  Hillingdon            325 non-null    int64
#  18  Hounslow              325 non-null    int64
#  19  Islington             325 non-null    int64
#  20  Kensington & Chelsea  325 non-null    int64
#  21  Kingston upon Thames  325 non-null    int64
#  22  Lambeth               325 non-null    int64
#  23  Lewisham              325 non-null    int64
#  24  Merton                325 non-null    int64
#  25  Newham                325 non-null    int64
#  26  Redbridge             325 non-null    int64
#  27  Richmond upon Thames  325 non-null    int64
#  28  Southwark             325 non-null    int64
#  29  Sutton                325 non-null    int64
#  30  Tower Hamlets         325 non-null    int64
#  31  Waltham Forest        325 non-null    int64
#  32  Wandsworth            325 non-null    int64
#  33  Westminster           325 non-null    int64
#  34  Inner London          325 non-null    int64
#  35  Outer London          325 non-null    int64
#  36  NORTH EAST            325 non-null    int64
#  37  NORTH WEST            325 non-null    int64
#  38  YORKS & THE HUMBER    325 non-null    int64
#  39  EAST MIDLANDS         325 non-null    int64
#  40  WEST MIDLANDS         325 non-null    int64
#  41  EAST OF ENGLAND       325 non-null    int64
#  42  LONDON                325 non-null    int64
#  43  SOUTH EAST            325 non-null    int64
#  44  SOUTH WEST            325 non-null    int64
#  45  England               325 non-null    int64
# dtypes: int64(45), object(1)
# memory usage: 116.9+ KB

# %%
data.head()
# Out:
#       Time  City of London  Barking & Dagenham  Barnet  Bexley  Brent  \
# 0  1995/01              17                  96     332     269    233
# 1  1995/02               7                  95     327     207    220
# 2  1995/03              14                 144     384     318    320
# 3  1995/04               7                 109     304     253    249
# 4  1995/05              10                 149     393     317    293
#
#    Bromley  Camden  Croydon  Ealing  ...  NORTH EAST  NORTH WEST  \
# 0      323     198      375     303  ...        1983        5801
# 1      326     194      342     242  ...        1986        6129
# 2      449     207      447     377  ...        3052        8375
# 3      362     174      377     270  ...        2406        6714
# 4      428     220      449     345  ...        2857        7641
#
#    YORKS & THE HUMBER  EAST MIDLANDS  WEST MIDLANDS  EAST OF ENGLAND  LONDON  \
# 0                4489           3990           4199             5812    7506
# 1                4349           4211           4633             5928    6873
# 2                6149           5840           6262             8374    9639
# 3                5338           4892           5218             7004    8053
# 4                6200           5377           6094             7765    9293
#
#    SOUTH EAST  SOUTH WEST  England
# 0        8809        5050    47639
# 1        8658        5113    47880
# 2       12177        7157    67025
# 3       10941        6359    56925
# 4       11975        6990    64192
#
# [5 rows x 46 columns]

# %%
df=data

# %%
df.head()
# Out:
#       Time  City of London  Barking & Dagenham  Barnet  Bexley  Brent  \
# 0  1995/01              17                  96     332     269    233
# 1  1995/02               7                  95     327     207    220
# 2  1995/03              14                 144     384     318    320
# 3  1995/04               7                 109     304     253    249
# 4  1995/05              10                 149     393     317    293
#
#    Bromley  Camden  Croydon  Ealing  ...  NORTH EAST  NORTH WEST  \
# 0      323     198      375     303  ...        1983        5801
# 1      326     194      342     242  ...        1986        6129
# 2      449     207      447     377  ...        3052        8375
# 3      362     174      377     270  ...        2406        6714
# 4      428     220      449     345  ...        2857        7641
#
#    YORKS & THE HUMBER  EAST MIDLANDS  WEST MIDLANDS  EAST OF ENGLAND  LONDON  \
# 0                4489           3990           4199             5812    7506
# 1                4349           4211           4633             5928    6873
# 2                6149           5840           6262             8374    9639
# 3                5338           4892           5218             7004    8053
# 4                6200           5377           6094             7765    9293
#
#    SOUTH EAST  SOUTH WEST  England
# 0        8809        5050    47639
# 1        8658        5113    47880
# 2       12177        7157    67025
# 3       10941        6359    56925
# 4       11975        6990    64192
#
# [5 rows x 46 columns]

# %%
# Setup matplotlib
import matplotlib.pyplot as plt

# Create an axes object 
axes = plt.gca()

# pass the axes object to plot function
df.plot(kind='line', x='Time', y='Inner London', ax=axes);
df.plot(kind='line', x='Time', y='Outer London', ax=axes);
df.plot(kind='line', x='Time', y='LONDON', ax=axes);

# %%
# Setup matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))

# Create an axes object 
axes = plt.gca()

# pass the axes object to plot function
df.plot(kind='line', x='Time', y='City of London', ax=axes);
df.plot(kind='line', x='Time', y='Barking & Dagenham', ax=axes);
df.plot(kind='line', x='Time', y='Barnet', ax=axes);
df.plot(kind='line', x='Time', y='Bexley', ax=axes);
df.plot(kind='line', x='Time', y='Brent', ax=axes);
df.plot(kind='line', x='Time', y='Bromley', ax=axes);
df.plot(kind='line', x='Time', y='Camden', ax=axes);
df.plot(kind='line', x='Time', y='Croydon', ax=axes);
df.plot(kind='line', x='Time', y='Ealing', ax=axes);
df.plot(kind='line', x='Time', y='Enfield', ax=axes);
df.plot(kind='line', x='Time', y='Greenwich', ax=axes);
df.plot(kind='line', x='Time', y='Hackney', ax=axes);
df.plot(kind='line', x='Time', y='Hammersmith & Fulham', ax=axes);
df.plot(kind='line', x='Time', y='Haringey', ax=axes);
df.plot(kind='line', x='Time', y='Harrow', ax=axes);
df.plot(kind='line', x='Time', y='Havering', ax=axes);
df.plot(kind='line', x='Time', y='Hillingdon', ax=axes);
df.plot(kind='line', x='Time', y='Hounslow', ax=axes);
df.plot(kind='line', x='Time', y='Islington', ax=axes);
df.plot(kind='line', x='Time', y='Kensington & Chelsea', ax=axes);
df.plot(kind='line', x='Time', y='Kingston upon Thames', ax=axes);
df.plot(kind='line', x='Time', y='Lambeth', ax=axes);
df.plot(kind='line', x='Time', y='Lewisham', ax=axes);
df.plot(kind='line', x='Time', y='Merton', ax=axes);
df.plot(kind='line', x='Time', y='Newham', ax=axes);
df.plot(kind='line', x='Time', y='Redbridge', ax=axes);
df.plot(kind='line', x='Time', y='Richmond upon Thames', ax=axes);
df.plot(kind='line', x='Time', y='Southwark', ax=axes);
df.plot(kind='line', x='Time', y='Sutton', ax=axes);
df.plot(kind='line', x='Time', y='Tower Hamlets', ax=axes);
df.plot(kind='line', x='Time', y='Waltham Forest', ax=axes);
df.plot(kind='line', x='Time', y='Wandsworth', ax=axes);
df.plot(kind='line', x='Time', y='Westminster', ax=axes);

# %%
df.plot(x='Time', y='City of London')

# %%
df.plot(x='Time', y='Barking & Dagenham')

# %%
df.plot(x='Time', y='Barnet')

# %%
df.plot(x='Time', y='Bexley')

# %%
df.plot(x='Time', y='Brent')

# %%
df.plot(x='Time', y='Bromley')

# %%
df.plot(x='Time', y='Camden')

# %%
df.plot(x='Time', y='Croydon')

# %%
df.plot(x='Time', y='Ealing')

# %%
df.plot(x='Time', y='Enfield')

# %%
df.plot(x='Time', y='Greenwich')

# %%
df.plot(x='Time', y='Hackney')

# %%
df.plot(x='Time', y='Hammersmith & Fulham')

# %%
df.plot(x='Time', y='Haringey')

# %%
df.plot(x='Time', y='Harrow')

# %%
df.plot(x='Time', y='Havering')

# %%
df.plot(x='Time', y='Hillingdon')

# %%
df.plot(x='Time', y='Hounslow')

# %%
df.plot(x='Time', y='Islington')

# %%
df.plot(x='Time', y='Kensington & Chelsea')

# %%
df.plot(x='Time', y='Kingston upon Thames')

# %%
df.plot(x='Time', y='Lambeth')

# %%
df.plot(x='Time', y='Lewisham')

# %%
df.plot(x='Time', y='Merton')

# %%
df.plot(x='Time', y='Newham')

# %%
df.plot(x='Time', y='Redbridge')

# %%
df.plot(x='Time', y='Richmond upon Thames')

# %%
df.plot(x='Time', y='Southwark')

# %%
df.plot(x='Time', y='Sutton')

# %%
df.plot(x='Time', y='Tower Hamlets')

# %%
df.plot(x='Time', y='Waltham Forest')

# %%
df.plot(x='Time', y='Wandsworth')

# %%
df.plot(x='Time', y='Westminster')

# %%
df.plot(x='Time', y='LONDON')

# %%
df.plot(x='Time', y='Inner London')

# %%
df.plot(x='Time', y='Outer London')

# %%
df.head()
# Out:
#       Time  City of London  Barking & Dagenham  Barnet  Bexley  Brent  \
# 0  1995/01              17                  96     332     269    233
# 1  1995/02               7                  95     327     207    220
# 2  1995/03              14                 144     384     318    320
# 3  1995/04               7                 109     304     253    249
# 4  1995/05              10                 149     393     317    293
#
#    Bromley  Camden  Croydon  Ealing  ...  NORTH EAST  NORTH WEST  \
# 0      323     198      375     303  ...        1983        5801
# 1      326     194      342     242  ...        1986        6129
# 2      449     207      447     377  ...        3052        8375
# 3      362     174      377     270  ...        2406        6714
# 4      428     220      449     345  ...        2857        7641
#
#    YORKS & THE HUMBER  EAST MIDLANDS  WEST MIDLANDS  EAST OF ENGLAND  LONDON  \
# 0                4489           3990           4199             5812    7506
# 1                4349           4211           4633             5928    6873
# 2                6149           5840           6262             8374    9639
# 3                5338           4892           5218             7004    8053
# 4                6200           5377           6094             7765    9293
#
#    SOUTH EAST  SOUTH WEST  England
# 0        8809        5050    47639
# 1        8658        5113    47880
# 2       12177        7157    67025
# 3       10941        6359    56925
# 4       11975        6990    64192
#
# [5 rows x 46 columns]

# %%
df[[ "year", "month"]] = df["Time"].str.split("/", expand = True)
df.head()
# Out:
#       Time  City of London  Barking & Dagenham  Barnet  Bexley  Brent  \
# 0  1995/01              17                  96     332     269    233
# 1  1995/02               7                  95     327     207    220
# 2  1995/03              14                 144     384     318    320
# 3  1995/04               7                 109     304     253    249
# 4  1995/05              10                 149     393     317    293
#
#    Bromley  Camden  Croydon  Ealing  ...  YORKS & THE HUMBER  EAST MIDLANDS  \
# 0      323     198      375     303  ...                4489           3990
# 1      326     194      342     242  ...                4349           4211
# 2      449     207      447     377  ...                6149           5840
# 3      362     174      377     270  ...                5338           4892
# 4      428     220      449     345  ...                6200           5377
#
#    WEST MIDLANDS  EAST OF ENGLAND  LONDON  SOUTH EAST  SOUTH WEST  England  \
# 0           4199             5812    7506        8809        5050    47639
# 1           4633             5928    6873        8658        5113    47880
# 2           6262             8374    9639       12177        7157    67025
# 3           5218             7004    8053       10941        6359    56925
# 4           6094             7765    9293       11975        6990    64192
#
#    year  month
# 0  1995     01
# 1  1995     02
# 2  1995     03
# 3  1995     04
# 4  1995     05
#
# [5 rows x 48 columns]
